# %%
# ---------------------------------------
# Environment & Project Root Alignment
# ---------------------------------------
import sys
import os
from pathlib import Path

# Append the root folder
project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
if project_root not in sys.path:
    sys.path.append(project_root)

# Import model training and inference scripts
from src.modeling.train import train_incident_model
from src.modeling.test import evaluate_test_performance

CONFIG_PATH = "/teamspace/studios/this_studio/airport-incident-detection/data/processed/config"

print("🚀 Modules imported successfully!")
# Out:
# 🚀 Modules imported successfully!

# %%
# ---------------------------------------
# Define Data Paths & Trigger Training
# ---------------------------------------

DATA_YAML ={
    'turnaround_model': str(CONFIG_PATH / "turnaround_data.yaml"),
    'ppe_model': str(CONFIG_PATH / "ppe_data.yaml"),
    'fod_model': str(CONFIG_PATH / "fod_data.yaml")
}
MODEL_VARIANT = "yolov8n.pt"

for model_name, yaml_path in DATA_YAML.items(): exit()
