# %%
import os
from torch.utils.tensorboard import SummaryWriter

# 1. Force rebuild the exact absolute log path TensorBoard is panicking about
absolute_log_dir = "/teamspace/studios/this_studio/airport-incident-detection/models/logs/phase1"
os.makedirs(absolute_log_dir, exist_ok=True)

# 2. Re-instantiate the global writer object to patch the broken thread stream
writer = SummaryWriter(log_dir=absolute_log_dir)
print("🎯 TensorBoard logging stream hot-patched and restored successfully.")
# Out:
# 🎯 TensorBoard logging stream hot-patched and restored successfully.
